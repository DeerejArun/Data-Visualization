# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('gas_prices.csv')

data.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
plt.title('Gas Prices in various countries', fontdict={'fontweight':'bold', 'fontsize': 20})

plt.plot(data.Year, data.France, 'b.-', label='France')
plt.plot(data.Year, data.Germany, 'y.-', label='Germany')
plt.plot(data.Year, data.Japan, 'r.-', label='Japan')
plt.plot(data.Year, data.UK, 'g.-', label='UK')

plt.xticks(data.Year[::3].tolist()+[2010])


plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.show()

# %%
plt.title('Gas Prices in various countries', fontdict={'fontweight':'bold', 'fontsize': 20})

plt.plot(data.Year, data.Australia, 'b.-', label='Australia')
plt.plot(data.Year, data.USA, 'y.-', label='USA')
plt.plot(data.Year, data.Mexico, 'r.-', label='Mexico')
plt.plot(data.Year, data.Canada, 'g.-', label='Canada')
plt.plot(data.Year, data['South Korea'], '#abcdef.-', label='South Korea')
plt.plot(data.Year, data.Italy, 'aabbcc.-', label='Italy')
plt.xticks(data.Year[::3].tolist()+[2010])


plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-8fb4ce95ab27> in <module>
#       5 plt.plot(data.Year, data.Mexico, 'r.-', label='Mexico')
#       6 plt.plot(data.Year, data.Canada, 'g.-', label='Canada')
# ----> 7 plt.plot(data.Year, data['South Korea'], '#abcdef.-', label='South Korea')
#       8 plt.plot(data.Year, data.Italy, 'aabbcc.-', label='Italy')
#       9 plt.xticks(data.Year[::3].tolist()+[2010])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
# ...
